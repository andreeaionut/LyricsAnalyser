# %%
import pandas as pd

data = pd.read_pickle('dtm.pkl')
data = data.transpose()
data.head()

data_clean = pd.read_pickle('data_clean.pkl')

# %%
#top 10 words for each artist
top_words_dict = {}
for c in data.columns:
    top = data[c].sort_values(ascending=False).head(10)
    top_words_dict[c]= list(zip(top.index, top.values))

top_words_dict
# Out:
# {'The Beatles': [('come', 45),
#   ('want', 33),
#   ('sun', 29),
#   ('love', 22),
#   ('time', 22),
#   ('say', 19),
#   ('sky', 18),
#   ('bad', 17),
#   ('good', 16),
#   ('diamond', 15)],
#  'The Rolling Stones': [('come', 61),
#   ('baby', 61),
#   ('gon', 57),
#   ('let', 52),
#   ('want', 43),
#   ('away', 33),
#   ('need', 30),
#   ('happy', 29),
#   ('love', 28),
#   ('roll', 25)],
#  'Elton John': [('saturday', 36),
#   ('tell', 27),
#   ('love', 26),
#   ('say', 25),
#   ('life', 23),
#   ('old', 21),
#   ('meal', 21),
#   ('time', 20),
#   ('ticket', 19),
#   ('tonight', 19)],
#  'Mariah Carey': [('baby', 97),
#   ('feel', 54),
#   ('fly', 45),
#   ('away', 44),
#   ('time', 43),
#   ('butterfly', 39),
#   ('want', 38),
#   ('love', 38),
#   ('sweet', 37),
#   ('night', 34)],
#  'Madonna': [('love', 86),
#   ('want', 33),
#   ('feel', 32),
#   ('heart', 31),
#   ('say', 25),
#   ('candy', 24),
#   ('time', 23),
#   ('life', 23),
#   ('forget', 23),
#   ('eye', 23)],
#  'Michael Jackson': [('love', 91),
#   ('baby', 80),
#   ('girl', 77),
#   ('say', 69),
#   ('really', 59),
#   ('bad', 54),
#   ('okay', 51),
#   ('beat', 51),
#   ('annie', 48),
#   ('time', 40)],
#  'Taylor Swift': [('love', 108),
#   ('wish', 86),
#   ('say', 82),
#   ('shake', 72),
#   ('baby', 47),
#   ('come', 46),
#   ('gon', 42),
#   ('stay', 38),
#   ('wood', 38),
#   ('new', 37)],
#  'Stevie Wonder': [('love', 187),
#   ('day', 111),
#   ('sucker', 60),
#   ('life', 49),
#   ('pain', 47),
#   ('say', 42),
#   ('ordinary', 40),
#   ('heart', 39),
#   ('world', 38),
#   ('tell', 36)],
#  'Whitney Houston': [('love', 161),
#   ('baby', 54),
#   ('say', 48),
#   ('heart', 43),
#   ('yes', 42),
#   ('come', 37),
#   ('think', 36),
#   ('good', 36),
#   ('wont', 33),
#   ('time', 33)],
#  'Elvis Presley': [('love', 87),
#   ('say', 54),
#   ('baby', 39),
#   ('day', 34),
#   ('hold', 26),
#   ('blue', 21),
#   ('good', 20),
#   ('away', 20),
#   ('strong', 18),
#   ('shoop', 18)],
#  'Drake': [('nigga', 144),
#   ('shit', 101),
#   ('girl', 84),
#   ('preach', 82),
#   ('say', 78),
#   ('right', 75),
#   ('love', 71),
#   ('fuck', 70),
#   ('time', 65),
#   ('man', 65)],
#  'Queen': [('love', 55),
#   ('late', 36),
#   ('come', 31),
#   ('say', 29),
#   ('listen', 26),
#   ('away', 25),
#   ('time', 25),
#   ('feel', 24),
#   ('hey', 22),
#   ('sweet', 21)]}

# %%
from sklearn.feature_extraction import text 

new_stop_words = ['aaah', 'aah', 'aaow', 'laa', 'ooh', 'ba', 'do', 'dodo', 'just', 'dont', 'gonna', 'bit', 'oh', 'im', 'like', 'little', 'cause', 'way',
                 'youre', 'youll', 'yeah', 'make', 'dont', 'wanna', 'na', 'somethin', 'something',
                 'know', 'ill', 'ive', 'youve', 'thats', 'shes', 'aint', 'la', 'getting', 'got', 'theyve']

stop_words = text.ENGLISH_STOP_WORDS.union(new_stop_words)

from wordcloud import WordCloud

wc = WordCloud(collocations=False, stopwords=stop_words, background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42)

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [20, 6]

artists_names =  ['The Beatles', 'The Rolling Stones', 'Elton John', 'Mariah Carey', 'Madonna', 'Michael Jackson', 'Taylor Swift', 'Stevie Wonder', 'Whitney Houston', 'Elvis Presley', 'Drake', 'Queen']

for index, artist in enumerate(data.columns):
    wc.generate(data_clean.lyrics[artist])
    
    plt.subplot(3, 4, index+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(artists_names[index])
    
plt.show()

# %%
#Vocabulary analysis - Number of unique words for each artist
uq_words = []
for artist in data.columns:
    uq_words.append((data[artist] != 0).sum())
uq_words
# Out:
# [670, 791, 946, 672, 589, 623, 729, 870, 509, 445, 1674, 736]

# %%
uq_words_df = pd.DataFrame(list(zip(artists_names, uq_words)), columns = ['Artist', 'Unique Words'])
uq_words_df.sort_values(by=['Unique Words'], ascending = False)
# Out:
#                 Artist  Unique Words
# 10               Drake          1674
# 2           Elton John           946
# 7        Stevie Wonder           870
# 1   The Rolling Stones           791
# 11               Queen           736
# 6         Taylor Swift           729
# 3         Mariah Carey           672
# 0          The Beatles           670
# 5      Michael Jackson           623
# 4              Madonna           589
# 8      Whitney Houston           509
# 9        Elvis Presley           445
